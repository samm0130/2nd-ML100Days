# %% [markdown]
# 作業1：
# The competition in Kaggle
# Two Sigma: Using News to Predict Stock Movements
# Use news analytics to predict stock price performance
# 1. 你選的這組資料為何重要
# two datas
# 1.Market data (2007 to present) provided by Intrinio - contains financial market information such as opening price, closing price, trading volume, calculated returns, etc.
# 2.News data (2007 to present) Source: Thomson Reuters - contains information about news articles/alerts published about assets, such as article details, sentiment, and other commentary.
#
# The prediction is to use 2 to forecast 1
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# Market data provided by Intrinio.
# News data provided by Thomson Reuters
#
# 3. 蒐集而來的資料型態為何
# structure and unstructured data
# 4. 這組資料想解決的問題如何評估
# The purpose of the competition is to analyze news data to predict stock price. The model accurancy would be the key to assess the model

# %% [markdown]
# Homework #2
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#   ＝>如何找出找出充分的客源以及利潤高的客群以提高整體業績
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# =>叫車app, 客戶資料分析
#
# 3. 蒐集而來的資料型態為何
# =>結構化資料 , 數值,文字
# ＝>非結構化資料資訊
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# =>客源分群, 尋找能創造大利潤的客群

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MAE
    """
    mae = MSE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 229.676
# The Mean absolute error is 12.424
